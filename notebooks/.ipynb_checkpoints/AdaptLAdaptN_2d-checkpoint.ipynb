# %%
import gpflow
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../')
from GPHetero import hetero_kernels, hetero_likelihoods, hetero_gpmc
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa

# %%
def ell_function(x):
    x = 6 * x
    return (4 * (1. - np.sin(x[0] + 8 * np.exp(x[0] - 7.))) \
        - 10.) / 5. + 6

# %%
np.random.seed(50)

num_quad_points = 100

X_train = np.linspace(0, 1, num_quad_points)[:, None] # The 1D input space for generating a sample function
X_train_norm = (X_train - 0.5)/0.5
mu = np.zeros(num_quad_points)

ell_f = np.array([ell_function(x) for x in X_train])[:, None]

Cov = hetero_kernels.NonStationaryLengthscaleRBF()
Cov.signal_variance = 10.
Cov.signal_variance.fixed = True

K = Cov.compute_K(X_train, ell_f, X_train, ell_f)

Y_train = np.random.multivariate_normal(mu, K, 1).T
# Out:
# /Users/nimishawalgaonkar/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:17: RuntimeWarning: covariance is not positive-semidefinite.

# %%
plt.figure()
plt.plot(X_train,Y_train, '.')
plt.figure()
plt.plot(X_train, ell_f, '.')

# %%
#build the model
k1 = hetero_kernels.RBF(1)
k2 = hetero_kernels.RBF(1)
nonstat = hetero_kernels.NonStationaryLengthscaleRBF()
m = hetero_gpmc.GPMCAdaptLAdaptN(X_train_norm, Y_train, k1, k2, nonstat)

# %%
m.kern1.lengthscales.prior = gpflow.priors.Gamma(1., 1.)
m.kern1.variance = 1.
m.kern1.variance.fixed = True
#m.kern1.variance.prior = gpflow.priors.Gamma(1., 1.)

m.kern2.lengthscales.prior = gpflow.priors.Gamma(1., 1.)
m.kern2.variance = 0.001
m.kern2.variance.fixed = True

m.nonstat.signal_variance = .1
m.nonstat.signal_variance.fixed = True

# %%
m.optimize(maxiter=5000)
# Out:
#       fun: array([ 380.44916858])
#  hess_inv: <303x303 LbfgsInvHessProduct with dtype=float64>
#       jac: array([  2.12632971e-03,  -9.85570723e-04,  -4.20287947e-04,
#         -4.19860280e-04,  -1.24136793e-04,   9.07908670e-05,
#          1.51606746e-04,   1.33767963e-04,   9.42551915e-05,
#          5.53439332e-05,   1.61794778e-05,  -3.28288852e-05,
#         -9.71087476e-05,  -1.72134754e-04,  -2.44873890e-04,
#         -2.99247959e-04,  -3.22584882e-04,  -3.10776694e-04,
#         -2.70155033e-04,  -2.14842754e-04,  -1.60561722e-04,
#         -1.18377051e-04,  -9.18907114e-05,  -7.85221960e-05,
#         -7.27655255e-05,  -6.91119111e-05,  -6.37375533e-05,
#         -5.50934320e-05,  -4.37109827e-05,  -3.14718554e-05,
#         -2.06632968e-05,  -1.31693346e-05,  -1.00016240e-05,
#         -1.11897584e-05,  -1.59518301e-05,  -2.30282360e-05,
#         -3.10474768e-05,  -3.88090809e-05,  -4.54250331e-05,
#         -5.03347710e-05,  -5.32547774e-05,  -5.41157507e-05,
#         -5.30060065e-05,  -5.01244508e-05,  -4.57477455e-05,
#         -4.02134123e-05,  -3.39104966e-05,  -2.72645414e-05,
#         -2.07105712e-05,  -1.46565257e-05,  -9.44583377e-06,
#         -5.32547025e-06,  -2.42580461e-06,  -7.55017741e-07,
#         -2.09477970e-07,  -5.97479397e-07,  -1.67129004e-06,
#         -3.16204790e-06,  -4.81139242e-06,  -6.39624040e-06,
#         -7.74417034e-06,  -8.73953567e-06,  -9.32206524e-06,
#         -9.48010886e-06,  -9.24107052e-06,  -8.66068372e-06,
#         -7.81269126e-06,  -6.77936932e-06,  -5.64365653e-06,
#         -4.48283811e-06,  -3.36395917e-06,  -2.34075884e-06,
#         -1.45211230e-06,  -7.21663986e-07,  -1.58556222e-07,
#          2.40918344e-07,   4.90990315e-07,   6.13570370e-07,
#          6.35182105e-07,   5.83954614e-07,   4.86913730e-07,
#          3.67881960e-07,   2.46035366e-07,   1.35264764e-07,
#          4.41790739e-08,  -2.33197848e-08,  -6.71209048e-08,
#         -8.98430195e-08,  -9.57335967e-08,  -8.96802838e-08,
#         -7.64277903e-08,  -6.00182261e-08,  -4.35059162e-08,
#         -2.88870262e-08,  -1.72252240e-08,  -8.84626514e-09,
#         -3.56561557e-09,  -8.54626892e-10,   4.84886480e-11,
#          2.93669021e-11,   5.72813969e-04,  -4.05993460e-04,
#         -5.45248330e-04,  -4.03391929e-04,  -1.82075138e-04,
#         -4.35816482e-05,   1.24188476e-05,   2.34712709e-05,
#          1.37109585e-05,  -5.95596291e-06,  -3.15224742e-05,
#         -6.19385187e-05,  -9.70053553e-05,  -1.36158424e-04,
#         -1.77783684e-04,  -2.19048333e-04,  -2.56253972e-04,
#         -2.85575180e-04,  -3.03907014e-04,  -3.09526250e-04,
#         -3.02374811e-04,  -2.83930696e-04,  -2.56768310e-04,
#         -2.23981902e-04,  -1.88643515e-04,  -1.53410254e-04,
#         -1.20320334e-04,  -9.07553858e-05,  -6.55139671e-05,
#         -4.49371474e-05,  -2.90403713e-05,  -1.76249204e-05,
#         -1.03590840e-05,  -6.83043007e-06,  -6.57624130e-06,
#         -9.10057062e-06,  -1.38852124e-05,  -2.03995374e-05,
#         -2.81116989e-05,  -3.65017439e-05,  -4.50759724e-05,
#         -5.33813492e-05,  -6.10187764e-05,  -6.76542377e-05,
#         -7.30271367e-05,  -7.69553878e-05,  -7.93370255e-05,
#         -8.01482585e-05,  -7.94380693e-05,  -7.73196454e-05,
#         -7.39591354e-05,  -6.95624384e-05,  -6.43608848e-05,
#         -5.85967739e-05,  -5.25097206e-05,  -4.63246653e-05,
#         -4.02422097e-05,  -3.44316853e-05,  -2.90270899e-05,
#         -2.41257671e-05,  -1.97894840e-05,  -1.60474210e-05,
#         -1.29005102e-05,  -1.03265560e-05,  -8.28562991e-06,
#         -6.72531680e-06,  -5.58551016e-06,  -4.80255803e-06,
#         -4.31266562e-06,  -4.05454068e-06,  -3.97132502e-06,
#         -4.01189211e-06,  -4.13160841e-06,  -4.29266023e-06,
#         -4.46404254e-06,  -4.62129468e-06,  -4.74605714e-06,
#         -4.82550631e-06,  -4.85171651e-06,  -4.82098509e-06,
#         -4.73314907e-06,  -4.59091506e-06,  -4.39921849e-06,
#         -4.16462486e-06,  -3.89478110e-06,  -3.59792356e-06,
#         -3.28244607e-06,  -2.95652920e-06,  -2.62783156e-06,
#         -2.30324282e-06,  -1.98869931e-06,  -1.68906482e-06,
#         -1.40807740e-06,  -1.14836128e-06,  -9.11493750e-07,
#         -6.98115958e-07,  -5.08071090e-07,  -3.40566711e-07,
#         -1.94364428e-07,  -6.79896659e-08,  -7.50870069e-03,
#         -7.49484585e-04,  -4.01956614e-04,  -3.01199316e-04,
#         -6.50050535e-05,   1.34645970e-04,   2.38492641e-04,
#          2.60823366e-04,   2.33300344e-04,   1.80457730e-04,
#          1.11027035e-04,   2.27162411e-05,  -8.56189443e-05,
#         -2.05773527e-04,  -3.20528372e-04,  -4.09867683e-04,
#         -4.57816509e-04,  -4.57089078e-04,  -4.11753369e-04,
#         -3.37251573e-04,  -2.55658856e-04,  -1.86984881e-04,
#         -1.41664493e-04,  -1.18853772e-04,  -1.10263552e-04,
#         -1.05781115e-04,  -9.76081139e-05,  -8.19162999e-05,
#         -5.85864917e-05,  -2.99614136e-05,   6.31330005e-07,
#          3.00496760e-05,   5.59317873e-05,   7.67623432e-05,
#          9.16507990e-05,   1.00072464e-04,   1.01734948e-04,
#          9.66291011e-05,   8.52321903e-05,   6.87498088e-05,
#          4.91995992e-05,   2.91587015e-05,   1.12249848e-05,
#         -2.52787961e-06,  -1.08847702e-05,  -1.36089048e-05,
#         -1.13975186e-05,  -5.66691695e-06,   1.81029013e-06,
#          9.30943477e-06,   1.54869056e-05,   1.95835131e-05,
#          2.14634644e-05,   2.14748788e-05,   2.01926246e-05,
#          1.81747499e-05,   1.58365911e-05,   1.34475465e-05,
#          1.11822771e-05,   9.15813502e-06,   7.43805108e-06,
#          6.02104039e-06,   4.84984275e-06,   3.84309332e-06,
#          2.93412222e-06,   2.09277748e-06,   1.32066483e-06,
#          6.28280914e-07,   1.05426450e-08,  -5.66363152e-07,
#         -1.16276680e-06,  -1.85171750e-06,  -2.70094042e-06,
#         -3.75715011e-06,  -5.03595649e-06,  -6.51636768e-06,
#         -8.13593176e-06,  -9.78319581e-06,  -1.12887171e-05,
#         -1.24212469e-05,  -1.29000296e-05,  -1.24389631e-05,
#         -1.08384734e-05,  -8.11351764e-06,  -4.58581887e-06,
#         -8.42220026e-07,   2.46031132e-06,   4.83702988e-06,
#          6.11595604e-06,   6.41366786e-06,   6.00663516e-06,
#          5.19815213e-06,   4.23692764e-06,   3.29044712e-06,
#          2.45238220e-06,   1.76163431e-06,   1.22046392e-06,
#          8.09929270e-07,   5.03206592e-07,   2.74983785e-07,
#         -1.30965182e-03,   4.25539152e-04,  -0.00000000e+00])
#   message: 'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 64
#       nit: 54
#    status: 0
#   success: True
#         x: array([  1.12418258e+00,   4.49317984e-01,   1.06184573e-01,
#          1.68478631e-01,   2.13285072e-01,   2.04813701e-01,
#          1.66963212e-01,   1.31423444e-01,   1.08416972e-01,
#          9.71367364e-02,   9.46865838e-02,   9.84012939e-02,
#          1.05920762e-01,   1.14930521e-01,   1.23120695e-01,
#          1.28490443e-01,   1.29839025e-01,   1.27075356e-01,
#          1.21078834e-01,   1.13209302e-01,   1.04796880e-01,
#          9.68464876e-02,   8.99722441e-02,   8.44609179e-02,
#          8.03692798e-02,   7.76070039e-02,   7.59928204e-02,
#          7.52884475e-02,   7.52196648e-02,   7.54933285e-02,
#          7.58163549e-02,   7.59189744e-02,   7.55805171e-02,
#          7.46525314e-02,   7.30726438e-02,   7.08643634e-02,
#          6.81224587e-02,   6.49883034e-02,   6.16221957e-02,
#          5.81791681e-02,   5.47921222e-02,   5.15630696e-02,
#          4.85610935e-02,   4.58247701e-02,   4.33668781e-02,
#          4.11798188e-02,   3.92408359e-02,   3.75166658e-02,
#          3.59675667e-02,   3.45508345e-02,   3.32239293e-02,
#          3.19472734e-02,   3.06866945e-02,   2.94153830e-02,
#          2.81151896e-02,   2.67771003e-02,   2.54008219e-02,
#          2.39935404e-02,   2.25680622e-02,   2.11406364e-02,
#          1.97287843e-02,   1.83494123e-02,   1.70173846e-02,
#          1.57446216e-02,   1.45396956e-02,   1.34078321e-02,
#          1.23512009e-02,   1.13693838e-02,   1.04599215e-02,
#          9.61887150e-03,   8.84133157e-03,   8.12190087e-03,
#          7.45506852e-03,   6.83552437e-03,   6.25839270e-03,
#          5.71939195e-03,   5.21492272e-03,   4.74209268e-03,
#          4.29868341e-03,   3.88307136e-03,   3.49411641e-03,
#          3.13103226e-03,   2.79325640e-03,   2.48032906e-03,
#          2.19179721e-03,   1.92714449e-03,   1.68574671e-03,
#          1.46685490e-03,   1.26958907e-03,   1.09293777e-03,
#          9.35763464e-04,   7.96799282e-04,   6.74658886e-04,
#          5.67855129e-04,   4.74851634e-04,   3.94115235e-04,
#          3.24173511e-04,   2.63629565e-04,   2.11128281e-04,
#          1.65319144e-04,  -2.37377081e+00,  -4.58143723e-01,
#         -6.27703504e-01,  -6.56207175e-01,  -5.85523912e-01,
#         -4.86928364e-01,  -3.98486892e-01,  -3.29917244e-01,
#         -2.79818940e-01,  -2.44311341e-01,  -2.19763387e-01,
#         -2.03330382e-01,  -1.92877524e-01,  -1.86793869e-01,
#         -1.83829534e-01,  -1.82979589e-01,  -1.83410418e-01,
#         -1.84419281e-01,  -1.85417794e-01,  -1.85930649e-01,
#         -1.85601280e-01,  -1.84197042e-01,  -1.81608224e-01,
#         -1.77837909e-01,  -1.72982778e-01,  -1.67207600e-01,
#         -1.60717477e-01,  -1.53731950e-01,  -1.46463926e-01,
#         -1.39104843e-01,  -1.31816079e-01,  -1.24725621e-01,
#         -1.17928622e-01,  -1.11490394e-01,  -1.05450673e-01,
#         -9.98282710e-02,  -9.46255576e-02,  -8.98324653e-02,
#         -8.54298893e-02,  -8.13924668e-02,  -7.76907917e-02,
#         -7.42931440e-02,  -7.11668245e-02,  -6.82791804e-02,
#         -6.55983947e-02,  -6.30940984e-02,  -6.07378499e-02,
#         -5.85035118e-02,  -5.63675457e-02,  -5.43092310e-02,
#         -5.23108147e-02,  -5.03575866e-02,  -4.84378792e-02,
#         -4.65429898e-02,  -4.46670248e-02,  -4.28066722e-02,
#         -4.09609102e-02,  -3.91306674e-02,  -3.73184505e-02,
#         -3.55279590e-02,  -3.37637049e-02,  -3.20306551e-02,
#         -3.03339116e-02,  -2.86784371e-02,  -2.70688354e-02,
#         -2.55091848e-02,  -2.40029260e-02,  -2.25527982e-02,
#         -2.11608167e-02,  -1.98282856e-02,  -1.85558366e-02,
#         -1.73434882e-02,  -1.61907163e-02,  -1.50965319e-02,
#         -1.40595616e-02,  -1.30781246e-02,  -1.21503077e-02,
#         -1.12740322e-02,  -1.04471140e-02,  -9.66731603e-03,
#         -8.93239196e-03,  -8.24012191e-03,  -7.58834034e-03,
#         -6.97495791e-03,  -6.39797688e-03,  -5.85550284e-03,
#         -5.34575381e-03,  -4.86706582e-03,  -4.41789564e-03,
#         -3.99681707e-03,  -3.60250766e-03,  -3.23372726e-03,
#         -2.88929154e-03,  -2.56805001e-03,  -2.26887353e-03,
#         -1.99065505e-03,  -1.73231848e-03,  -1.49284107e-03,
#         -1.27130256e-03,  -1.06696354e-03,   4.82315649e+00,
#          1.09361919e+00,   1.55618173e-01,   7.79137690e-02,
#          5.59766328e-02,   4.97246969e-02,   4.87570272e-02,
#          4.90363083e-02,   4.93297307e-02,   4.99264263e-02,
#          5.15447019e-02,   5.46978391e-02,   5.95588480e-02,
#          6.60229156e-02,   7.37662875e-02,   8.22651450e-02,
#          9.08099414e-02,   9.85597005e-02,   1.04659869e-01,
#          1.08409211e-01,   1.09420218e-01,   1.07701658e-01,
#          1.03623273e-01,   9.77843231e-02,   9.08514382e-02,
#          8.34284302e-02,   7.59860602e-02,   6.88461693e-02,
#          6.21993772e-02,   5.61362720e-02,   5.06791287e-02,
#          4.58080613e-02,   4.14800065e-02,   3.76412773e-02,
#          3.42352970e-02,   3.12070766e-02,   2.85056857e-02,
#          2.60855380e-02,   2.39070104e-02,   2.19366001e-02,
#          2.01466721e-02,   1.85147233e-02,   1.70223210e-02,
#          1.56540169e-02,   1.43965057e-02,   1.32380320e-02,
#          1.21680117e-02,   1.11768700e-02,   1.02560865e-02,
#          9.39833208e-03,   8.59757155e-03,   7.84909442e-03,
#          7.14940253e-03,   6.49595920e-03,   5.88683914e-03,
#          5.32041098e-03,   4.79515051e-03,   4.30959132e-03,
#          3.86232873e-03,   3.45202250e-03,   3.07736901e-03,
#          2.73706955e-03,   2.42981385e-03,   2.15431074e-03,
#          1.90931314e-03,   1.69365291e-03,   1.50624375e-03,
#          1.34607316e-03,   1.21220235e-03,   1.10377557e-03,
#          1.02004483e-03,   9.60399498e-04,   9.24388423e-04,
#          9.11716589e-04,   9.22198127e-04,   9.55648720e-04,
#          1.01167890e-03,   1.08937767e-03,   1.18683724e-03,
#          1.30052370e-03,   1.42456654e-03,   1.55017254e-03,
#          1.66556109e-03,   1.75689828e-03,   1.81056463e-03,
#          1.81640633e-03,   1.77074810e-03,   1.67763132e-03,
#          1.54750563e-03,   1.39408110e-03,   1.23092594e-03,
#          1.06907670e-03,   9.16092892e-04,   7.76215087e-04,
#          6.51117855e-04,   5.40764879e-04,   4.44151584e-04,
#          3.59799712e-04,   2.86024902e-04,   2.21088616e-04,
#          6.89693021e-01,   1.22582385e+00,   5.41323273e-01])

# %%
samples = m.sample(2000, verbose=True, epsilon=0.01, thin = 2, burn = 1000, Lmax = 40)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  98.0 %
# Iteration:  200 	 Acc Rate:  100.0 %
# Iteration:  300 	 Acc Rate:  100.0 %
# Iteration:  400 	 Acc Rate:  100.0 %
# Iteration:  500 	 Acc Rate:  99.0 %
# Iteration:  600 	 Acc Rate:  100.0 %
# Iteration:  700 	 Acc Rate:  100.0 %
# Iteration:  800 	 Acc Rate:  100.0 %
# Iteration:  900 	 Acc Rate:  100.0 %
# Iteration:  1000 	 Acc Rate:  100.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  98.0 %
# Iteration:  200 	 Acc Rate:  100.0 %
# Iteration:  300 	 Acc Rate:  100.0 %
# Iteration:  400 	 Acc Rate:  100.0 %
# Iteration:  500 	 Acc Rate:  100.0 %
# Iteration:  600 	 Acc Rate:  100.0 %
# Iteration:  700 	 Acc Rate:  100.0 %
# Iteration:  800 	 Acc Rate:  100.0 %
# Iteration:  900 	 Acc Rate:  100.0 %
# Iteration:  1000 	 Acc Rate:  100.0 %
# Iteration:  1100 	 Acc Rate:  100.0 %
# Iteration:  1200 	 Acc Rate:  100.0 %
# Iteration:  1300 	 Acc Rate:  100.0 %
# Iteration:  1400 	 Acc Rate:  100.0 %
# Iteration:  1500 	 Acc Rate:  100.0 %
# Iteration:  1600 	 Acc Rate:  100.0 %
# Iteration:  1700 	 Acc Rate:  99.0 %
# Iteration:  1800 	 Acc Rate:  100.0 %
# Iteration:  1900 	 Acc Rate:  100.0 %
# Iteration:  2000 	 Acc Rate:  100.0 %
# Iteration:  2100 	 Acc Rate:  100.0 %
# Iteration:  2200 	 Acc Rate:  100.0 %
# Iteration:  2300 	 Acc Rate:  100.0 %
# Iteration:  2400 	 Acc Rate:  100.0 %
# Iteration:  2500 	 Acc Rate:  100.0 %
# Iteration:  2600 	 Acc Rate:  100.0 %
# Iteration:  2700 	 Acc Rate:  99.0 %
# Iteration:  2800 	 Acc Rate:  100.0 %
# Iteration:  2900 	 Acc Rate:  100.0 %
# Iteration:  3000 	 Acc Rate:  100.0 %
# Iteration:  3100 	 Acc Rate:  100.0 %
# Iteration:  3200 	 Acc Rate:  100.0 %
# Iteration:  3300 	 Acc Rate:  98.0 %
# Iteration:  3400 	 Acc Rate:  100.0 %
# Iteration:  3500 	 Acc Rate:  100.0 %
# Iteration:  3600 	 Acc Rate:  100.0 %
# Iteration:  3700 	 Acc Rate:  100.0 %
# Iteration:  3800 	 Acc Rate:  100.0 %
# Iteration:  3900 	 Acc Rate:  100.0 %
# Iteration:  4000 	 Acc Rate:  100.0 %

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>adapt_ll_noise_gps.V1</td><td>[[  1.12418258e+00]</br> [  4.49317984e-01]</br> [  1.06184573e-01]</br> [  1.68478631e-01]</br> [  2.13285072e-01]</br> [  2.04813701e-01]</br> [  1.66963212e-01]</br> [  1.31423444e-01]</br> [  1.08416972e-01]</br> [  9.71367364e-02]</br> [  9.46865838e-02]</br> [  9.84012939e-02]</br> [  1.05920762e-01]</br> [  1.14930521e-01]</br> [  1.23120695e-01]</br> [  1.28490443e-01]</br> [  1.29839025e-01]</br> [  1.27075356e-01]</br> [  1.21078834e-01]</br> [  1.13209302e-01]</br> [  1.04796880e-01]</br> [  9.68464876e-02]</br> [  8.99722441e-02]</br> [  8.44609179e-02]</br> [  8.03692798e-02]</br> [  7.76070039e-02]</br> [  7.59928204e-02]</br> [  7.52884475e-02]</br> [  7.52196648e-02]</br> [  7.54933285e-02]</br> [  7.58163549e-02]</br> [  7.59189744e-02]</br> [  7.55805171e-02]</br> [  7.46525314e-02]</br> [  7.30726438e-02]</br> [  7.08643634e-02]</br> [  6.81224587e-02]</br> [  6.49883034e-02]</br> [  6.16221957e-02]</br> [  5.81791681e-02]</br> [  5.47921222e-02]</br> [  5.15630696e-02]</br> [  4.85610935e-02]</br> [  4.58247701e-02]</br> [  4.33668781e-02]</br> [  4.11798188e-02]</br> [  3.92408359e-02]</br> [  3.75166658e-02]</br> [  3.59675667e-02]</br> [  3.45508345e-02]</br> [  3.32239293e-02]</br> [  3.19472734e-02]</br> [  3.06866945e-02]</br> [  2.94153830e-02]</br> [  2.81151896e-02]</br> [  2.67771003e-02]</br> [  2.54008219e-02]</br> [  2.39935404e-02]</br> [  2.25680622e-02]</br> [  2.11406364e-02]</br> [  1.97287843e-02]</br> [  1.83494123e-02]</br> [  1.70173846e-02]</br> [  1.57446216e-02]</br> [  1.45396956e-02]</br> [  1.34078321e-02]</br> [  1.23512009e-02]</br> [  1.13693838e-02]</br> [  1.04599215e-02]</br> [  9.61887150e-03]</br> [  8.84133157e-03]</br> [  8.12190087e-03]</br> [  7.45506852e-03]</br> [  6.83552437e-03]</br> [  6.25839270e-03]</br> [  5.71939195e-03]</br> [  5.21492272e-03]</br> [  4.74209268e-03]</br> [  4.29868341e-03]</br> [  3.88307136e-03]</br> [  3.49411641e-03]</br> [  3.13103226e-03]</br> [  2.79325640e-03]</br> [  2.48032906e-03]</br> [  2.19179721e-03]</br> [  1.92714449e-03]</br> [  1.68574671e-03]</br> [  1.46685490e-03]</br> [  1.26958907e-03]</br> [  1.09293777e-03]</br> [  9.35763464e-04]</br> [  7.96799282e-04]</br> [  6.74658886e-04]</br> [  5.67855129e-04]</br> [  4.74851634e-04]</br> [  3.94115235e-04]</br> [  3.24173511e-04]</br> [  2.63629565e-04]</br> [  2.11128281e-04]</br> [  1.65319144e-04]]</td><td>N([ 0.],[ 1.])</td><td>(none)</td></tr><tr><td>adapt_ll_noise_gps.V2</td><td>[[ -2.37377081e+00]</br> [ -4.58143723e-01]</br> [ -6.27703504e-01]</br> [ -6.56207175e-01]</br> [ -5.85523912e-01]</br> [ -4.86928364e-01]</br> [ -3.98486892e-01]</br> [ -3.29917244e-01]</br> [ -2.79818940e-01]</br> [ -2.44311341e-01]</br> [ -2.19763387e-01]</br> [ -2.03330382e-01]</br> [ -1.92877524e-01]</br> [ -1.86793869e-01]</br> [ -1.83829534e-01]</br> [ -1.82979589e-01]</br> [ -1.83410418e-01]</br> [ -1.84419281e-01]</br> [ -1.85417794e-01]</br> [ -1.85930649e-01]</br> [ -1.85601280e-01]</br> [ -1.84197042e-01]</br> [ -1.81608224e-01]</br> [ -1.77837909e-01]</br> [ -1.72982778e-01]</br> [ -1.67207600e-01]</br> [ -1.60717477e-01]</br> [ -1.53731950e-01]</br> [ -1.46463926e-01]</br> [ -1.39104843e-01]</br> [ -1.31816079e-01]</br> [ -1.24725621e-01]</br> [ -1.17928622e-01]</br> [ -1.11490394e-01]</br> [ -1.05450673e-01]</br> [ -9.98282710e-02]</br> [ -9.46255576e-02]</br> [ -8.98324653e-02]</br> [ -8.54298893e-02]</br> [ -8.13924668e-02]</br> [ -7.76907917e-02]</br> [ -7.42931440e-02]</br> [ -7.11668245e-02]</br> [ -6.82791804e-02]</br> [ -6.55983947e-02]</br> [ -6.30940984e-02]</br> [ -6.07378499e-02]</br> [ -5.85035118e-02]</br> [ -5.63675457e-02]</br> [ -5.43092310e-02]</br> [ -5.23108147e-02]</br> [ -5.03575866e-02]</br> [ -4.84378792e-02]</br> [ -4.65429898e-02]</br> [ -4.46670248e-02]</br> [ -4.28066722e-02]</br> [ -4.09609102e-02]</br> [ -3.913066 ...

# %%
sample_df = m.get_samples_df(samples)

# %%
mean_l_mat = np.zeros(shape = (samples.shape[0], X_train_norm.shape[0]))
var_l_mat = np.zeros(shape = (samples.shape[0], X_train_norm.shape[0]))

# %%
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    mean1, v1 = m.predict_l(X_train_norm)
    var1 = v1[:,:]
    mean_l_mat[i,:] = mean1[:,0]
    var_l_mat[i,:] = np.diag(var1)

std_l_mat = np.sqrt(var_l_mat)

# %%
LowerlogL = mean_l_mat - 2*std_l_mat
UpperlogL = mean_l_mat + 2*std_l_mat

# %%
MeanL = np.exp(mean_l_mat)
LowerL = np.exp(LowerlogL)
UpperL = np.exp(UpperlogL)

# %%
def visualize(Xgrid, M, L, U):
    """
    Visualize 1D utility funciton values
    Xgrid : grid states
    Mgrid : mean of GP at those finite grid points
    Vargrid : variance of GP at those finite grid points
    """
    
    line, = plt.plot(Xgrid, M, lw = 2, color = 'b', label = 'utility', alpha = 0.5)
    plt.fill_between(Xgrid[:,0], L, U,
                     color = 'b', alpha = 0.25)
    #plt.fill_between(Xgrid[:,0], lower1, upper1,
    #                 color = 'g', alpha = 0.25)
    plt.xlabel('x')
    plt.ylabel('y')
    return

# %%
mini = 505
maxi = 910
plt.figure(figsize=(12,8))
for i in xrange(mini,maxi):
    visualize(X_train_norm, MeanL[i,:], LowerL[i,:], UpperL[i,:])

# %%
mean_n_mat = np.zeros(shape = (samples.shape[0], X_train_norm.shape[0]))
var_n_mat = np.zeros(shape = (samples.shape[0], X_train_norm.shape[0]))

# %%
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    mean1, v1 = m.predict_n(X_train_norm)
    var1 = v1[:,:]
    mean_n_mat[i,:] = mean1[:,0]
    var_n_mat[i,:] = np.diag(var1)

std_n_mat = np.sqrt(var_n_mat)

# %%
LowerlogN = mean_n_mat - 2*std_n_mat
UpperlogN = mean_n_mat + 2*std_n_mat

# %%
MeanN = np.exp(mean_n_mat)
LowerN = np.exp(LowerlogN)
UpperN = np.exp(UpperlogN)

# %%
mini = 500
maxi = 1110
plt.figure(figsize=(12,8))
for i in xrange(mini,maxi):
    visualize(X_train, MeanN[i,:], LowerN[i,:], UpperN[i,:])

# %%
sig_samples = m.signal_variance.get_samples_df(samples)
signal_var = np.array([])
for s in sig_samples:
    signal_var = np.append(signal_var, s)

# %%
mean_f_mat = np.zeros(shape = (samples.shape[0], X_train_norm.shape[0]))
var_f_mat = np.zeros(shape = (samples.shape[0], X_train_norm.shape[0]))

for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    mean1, v1 = m.predict_f(X_train_norm)
    var1 = v1[:,:]
    mean_f_mat[i,:] = mean1[:,0]
    var_f_mat[i,:] = np.diag(var1)

# %%
std_f_mat = np.sqrt(var_f_mat)

# %%
Lowerf = mean_f_mat - 2*std_f_mat
Upperf = mean_f_mat + 2*std_f_mat

# %%
def visualize_all(Xgrid, M1, L1, U1, U2, signal_var):
    """
    Visualize
    """  
    L2 = L1 - U2
    U2 = U1 + U2
    
    plt.plot(X_train, Y_train, '.')
    line, = plt.plot(Xgrid, M1, lw = 2, color = 'b', label = 'utility', alpha = 0.5)
    plt.fill_between(Xgrid[:,0], L1, U1,
                     color = 'b', alpha = 0.25)
    plt.fill_between(Xgrid[:,0], L2, U2,
                     color = 'g', alpha = 0.25)
    plt.xlabel('x')
    plt.ylabel('y')
    return

# %%
mini = 1900
maxi = 1905
plt.figure(figsize=(12,8))
for i in xrange(mini,maxi):
    visualize_all(X_train, mean_f_mat[i,:],
              Lowerf[i,:], Upperf[i,:],
              UpperN[i,:], signal_var[i])
