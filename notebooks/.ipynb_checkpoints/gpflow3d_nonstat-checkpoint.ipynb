# %%
import gpflow
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import sys
sys.path.append('../')
from GPHetero import hetero_kernels, hetero_likelihoods, hetero_gpmc
from pyDOE import *
import os
from scipy.stats import norm
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xb but this version of numpy is 0xa

# %%
class Ex5Func(object):

    def __init__(self, sigma=lambda x: 0.5):
        self.sigma = sigma

    def __call__(self, x):
        """
        Dette et. al. function.
        Dette, Holger, and Andrey Pepelyshev. "Generalized Latin hypercube design for computer experiments." Technometrics 52, no. 4 (2010): 421-429.

        """
        y = 4 * ((x[0] - 2 + 8 * x[1] - 8 * (x[1] ** 2)) ** 2) + (3 - 4 * x[1]) ** 2 + 16 * np.sqrt(x[2] + 1) * ((2 * x[2] - 1)**2)
        return (y - 50) / 50.

# %%
dim = 3
n = 20
noise=0
sigma = eval('lambda x: ' + str(noise))

objective = Ex5Func(sigma=sigma)
X = lhs(dim, n , criterion='center')
Xnorm = (X - 0.5) /0.5
Y = np.array([objective(x) for x in X])[:, None]

# %%
#build the model
k = gpflow.kernels.RBF(input_dim=1)
k.lengthscales.prior = gpflow.priors.Gamma(1, 1)
# from copy import copy
# l = copy(k)
noisekern = gpflow.kernels.RBF(input_dim=1)
nonstat = hetero_kernels.NonStationaryLengthscaleRBF()
mean_func = gpflow.mean_functions.Constant(1)
m = hetero_gpmc.GPMCAdaptiveLengthscaleMultDim(Xnorm, Y, k, nonstat, mean_func)

# %%
for i in xrange(dim):
    print i
    m.kerns["ell" + str(i)].lengthscales.prior = gpflow.priors.Gamma(1., 1.)
    m.kerns["ell" + str(i)].variance.prior = gpflow.priors.Gamma(1., 1.)
    #m.mean_funcs["ell" + str(i)].c = 3.
    #m.mean_funcs["ell" + str(i)].c.fixed = True 
    m.mean_funcs["ell" + str(i)].c.prior = gpflow.priors.Exponential(1./4)
m.nonstat.signal_variance.prior = gpflow.priors.Gamma(1., 1.)
# m.nonstat.signal_variance.fixed = True
m.likelihood.variance = 1e-6
m.likelihood.variance.fixed = True
# Out:
# 0
# 1
# 2

# %%
m.optimize(maxiter=1500) # start near MAP
# Out:
#       fun: array([-32.29581572])
#  hess_inv: <83x83 LbfgsInvHessProduct with dtype=float64>
#       jac: array([  1.09561101e+01,  -6.20518359e+01,  -4.32332667e+01,
#         -1.50421885e+01,   9.61645569e+01,   2.92765232e+01,
#         -1.64179164e+01,  -3.08471161e+01,   4.94982267e+01,
#         -1.23914631e+01,   4.96840487e+01,  -1.33740971e+01,
#          7.55314011e+00,   1.76211279e+00,  -9.12187092e-01,
#          4.00973237e+00,   1.43118379e+01,   3.05043113e+00,
#         -6.08500575e-01,   3.54403175e+00,   2.12977147e+00,
#          1.45699726e+00,   1.15825647e+01,  -2.35535392e+00,
#         -2.11230777e+00,   1.17851600e+00,   3.07637614e+00,
#          1.03907281e+00,  -9.65169844e-01,  -9.10981216e-01,
#          1.32428835e+00,  -1.58620651e+00,   3.97130843e-01,
#         -1.38771289e+00,   5.85610492e-02,  -3.63672090e-01,
#          2.20266847e+00,   1.05764550e+00,   1.56511732e+00,
#          1.68026389e+00,  -2.02073933e+00,   1.66418752e-01,
#          4.11162154e-01,  -1.74377416e+00,  -3.70341554e+00,
#          1.40126246e+00,  -1.10230426e-01,  -4.58534657e-01,
#          5.56830836e-01,  -6.70522930e-01,  -1.31909380e+00,
#         -3.26029964e-01,   2.17887336e+00,   2.53314753e+00,
#         -9.54940682e-02,  -3.36494100e+00,  -2.55557859e+00,
#          5.37570020e-02,   1.06631347e+00,   8.74370638e-01,
#          1.18328746e+02,   2.71958593e+01,  -8.18281327e+00,
#          1.46347250e+00,  -1.48067734e+01,   4.99775939e-01,
#          4.97358558e+00,   1.29287064e+00,  -1.19755716e+00,
#         -2.95179024e+00,   3.45511238e+00,  -2.37582686e+00,
#          7.20871814e-01,   3.45775528e+00,  -2.10632459e+00,
#         -3.80915911e+00,  -2.49234213e+00,   2.75870739e+00,
#         -2.76309137e+00,   9.79329634e-01,   6.34151021e+00,
#         -1.27344821e+01,  -1.79817378e+01])
#   message: 'STOP: TOTAL NO. of ITERATIONS EXCEEDS LIMIT'
#      nfev: 1692
#       nit: 1501
#    status: 1
#   success: False
#         x: array([ 0.04932605, -0.34450438, -0.46498703, -0.0579642 , -0.43694379,
#        -0.47930486,  0.22703085, -0.29244352,  0.10814633, -0.03314119,
#        -0.48820994, -0.33043085, -0.64942358, -0.80228922, -0.59229916,
#         0.02946246, -0.30437429,  0.20007415, -0.05246082, -0.18617887,
#        -0.50625361,  0.02884553, -0.48883857,  0.15052438,  0.20238014,
#        -0.02032259, -0.26602043, -0.01362285,  0.24238461,  0.32949703,
#        -0.08330773, -0.26723307, -0.51738035,  0.10715949,  0.2933007 ,
#         0.23857249, -0.18682994,  0.26628661,  0.45918492, -0.1978251 ,
#         0.62655945,  0.42640757,  0.05052048, -0.46718087, -0.43038169,
#        -0.06947323,  0.26149501,  0.27276798, -0.01766457,  0.00669026,
#         0.18343769,  0.1610452 , -0.97598763, -0.91832276, -0.04258117,
#         0.38584262,  0.29124087,  0.0197091 , -0.16881195, -0.16428701,
#        -0.30093654, -1.76772015,  0.31062235,  0.28930078, -0.72250372,
#        -0.41670427, -0.32367693, -0.19413143,  0.42549   , -0.30023071,
#        -0.56390981,  1.08880606,  0.9393986 ,  0.3707648 , -0.68234842,
#         0.19129323, -0.3846574 , -1.31181006,  0.46552157, -0.26646597,
#         0.44143952,  0.58433731,  1.97533026])

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>adaptive_lengthscale_gp_multdim.V</td><td>[[ 0.04932605 -0.34450438 -0.46498703]</br> [-0.0579642  -0.43694379 -0.47930486]</br> [ 0.22703085 -0.29244352  0.10814633]</br> [-0.03314119 -0.48820994 -0.33043085]</br> [-0.64942358 -0.80228922 -0.59229916]</br> [ 0.02946246 -0.30437429  0.20007415]</br> [-0.05246082 -0.18617887 -0.50625361]</br> [ 0.02884553 -0.48883857  0.15052438]</br> [ 0.20238014 -0.02032259 -0.26602043]</br> [-0.01362285  0.24238461  0.32949703]</br> [-0.08330773 -0.26723307 -0.51738035]</br> [ 0.10715949  0.2933007   0.23857249]</br> [-0.18682994  0.26628661  0.45918492]</br> [-0.1978251   0.62655945  0.42640757]</br> [ 0.05052048 -0.46718087 -0.43038169]</br> [-0.06947323  0.26149501  0.27276798]</br> [-0.01766457  0.00669026  0.18343769]</br> [ 0.1610452  -0.97598763 -0.91832276]</br> [-0.04258117  0.38584262  0.29124087]</br> [ 0.0197091  -0.16881195 -0.16428701]]</td><td>N([ 0.],[ 1.])</td><td>(none)</td></tr><tr><td>adaptive_lengthscale_gp_multdim.V4</td><td>[[-0.30093654]</br> [-1.76772015]</br> [ 0.31062235]</br> [ 0.28930078]</br> [-0.72250372]</br> [-0.41670427]</br> [-0.32367693]</br> [-0.19413143]</br> [ 0.42549   ]</br> [-0.30023071]</br> [-0.56390981]</br> [ 1.08880606]</br> [ 0.9393986 ]</br> [ 0.3707648 ]</br> [-0.68234842]</br> [ 0.19129323]</br> [-0.3846574 ]</br> [-1.31181006]</br> [ 0.46552157]</br> [-0.26646597]]</td><td>N([ 0.],[ 1.])</td><td>(none)</td></tr><tr><td>adaptive_lengthscale_gp_multdim.kern_type.lengthscales</td><td>[ 0.9380313]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>adaptive_lengthscale_gp_multdim.kern_type.variance</td><td>[ 1.02740434]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>adaptive_lengthscale_gp_multdim.likelihood.variance</td><td>[  1.00000000e-06]</td><td>None</td><td>[FIXED]</td></tr><tr><td>adaptive_lengthscale_gp_multdim.mean_func.c</td><td>[ 3.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>adaptive_lengthscale_gp_multdim.nonstat.signal_variance</td><td>[ 2.10523213]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr></table>

# %%
mcmc_samples = 1000
num_samp_gp = 1

# %%
samples = m.sample(mcmc_samples, verbose=True, epsilon=0.00005, thin = 5, burn = 500, Lmax = 20)
# Out:
# burn-in sampling started
# Iteration:  100 	 Acc Rate:  97.0 %
# Iteration:  200 	 Acc Rate:  97.0 %
# Iteration:  300 	 Acc Rate:  99.0 %
# Iteration:  400 	 Acc Rate:  99.0 %
# Iteration:  500 	 Acc Rate:  98.0 %
# burn-in sampling ended
# Iteration:  100 	 Acc Rate:  97.0 %
# Iteration:  200 	 Acc Rate:  100.0 %
# Iteration:  300 	 Acc Rate:  98.0 %
# Iteration:  400 	 Acc Rate:  99.0 %
# Iteration:  500 	 Acc Rate:  98.0 %
# Iteration:  600 	 Acc Rate:  99.0 %
# Iteration:  700 	 Acc Rate:  100.0 %
# Iteration:  800 	 Acc Rate:  100.0 %
# Iteration:  900 	 Acc Rate:  99.0 %
# Iteration:  1000 	 Acc Rate:  99.0 %
# Iteration:  1100 	 Acc Rate:  98.0 %
# Iteration:  1200 	 Acc Rate:  99.0 %
# Iteration:  1300 	 Acc Rate:  98.0 %
# Iteration:  1400 	 Acc Rate:  100.0 %
# Iteration:  1500 	 Acc Rate:  100.0 %
# Iteration:  1600 	 Acc Rate:  100.0 %
# Iteration:  1700 	 Acc Rate:  100.0 %
# Iteration:  1800 	 Acc Rate:  96.0 %
# Iteration:  1900 	 Acc Rate:  98.0 %
# Iteration:  2000 	 Acc Rate:  99.0 %
# Iteration:  2100 	 Acc Rate:  98.0 %
# Iteration:  2200 	 Acc Rate:  100.0 %
# Iteration:  2300 	 Acc Rate:  99.0 %
# Iteration:  2400 	 Acc Rate:  99.0 %
# Iteration:  2500 	 Acc Rate:  96.0 %
# Iteration:  2600 	 Acc Rate:  100.0 %
# Iteration:  2700 	 Acc Rate:  100.0 %
# Iteration:  2800 	 Acc Rate:  99.0 %
# Iteration:  2900 	 Acc Rate:  100.0 %
# Iteration:  3000 	 Acc Rate:  97.0 %
# Iteration:  3100 	 Acc Rate:  97.0 %
# Iteration:  3200 	 Acc Rate:  98.0 %
# Iteration:  3300 	 Acc Rate:  100.0 %
# Iteration:  3400 	 Acc Rate:  99.0 %
# Iteration:  3500 	 Acc Rate:  99.0 %
# Iteration:  3600 	 Acc Rate:  99.0 %
# Iteration:  3700 	 Acc Rate:  98.0 %
# Iteration:  3800 	 Acc Rate:  100.0 %
# Iteration:  3900 	 Acc Rate:  96.0 %
# Iteration:  4000 	 Acc Rate:  100.0 %
# Iteration:  4100 	 Acc Rate:  98.0 %
# Iteration:  4200 	 Acc Rate:  99.0 %
# Iteration:  4300 	 Acc Rate:  100.0 %
# Iteration:  4400 	 Acc Rate:  99.0 %
# Iteration:  4500 	 Acc Rate:  100.0 %
# Iteration:  4600 	 Acc Rate:  99.0 %
# Iteration:  4700 	 Acc Rate:  98.0 %
# Iteration:  4800 	 Acc Rate:  100.0 %
# Iteration:  4900 	 Acc Rate:  99.0 %
# Iteration:  5000 	 Acc Rate:  99.0 %

# %%
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>adaptive_lengthscale_gp_multdim.V</td><td>[[ 0.04932605 -0.34450438 -0.46498703]</br> [-0.0579642  -0.43694379 -0.47930486]</br> [ 0.22703085 -0.29244352  0.10814633]</br> [-0.03314119 -0.48820994 -0.33043085]</br> [-0.64942358 -0.80228922 -0.59229916]</br> [ 0.02946246 -0.30437429  0.20007415]</br> [-0.05246082 -0.18617887 -0.50625361]</br> [ 0.02884553 -0.48883857  0.15052438]</br> [ 0.20238014 -0.02032259 -0.26602043]</br> [-0.01362285  0.24238461  0.32949703]</br> [-0.08330773 -0.26723307 -0.51738035]</br> [ 0.10715949  0.2933007   0.23857249]</br> [-0.18682994  0.26628661  0.45918492]</br> [-0.1978251   0.62655945  0.42640757]</br> [ 0.05052048 -0.46718087 -0.43038169]</br> [-0.06947323  0.26149501  0.27276798]</br> [-0.01766457  0.00669026  0.18343769]</br> [ 0.1610452  -0.97598763 -0.91832276]</br> [-0.04258117  0.38584262  0.29124087]</br> [ 0.0197091  -0.16881195 -0.16428701]]</td><td>N([ 0.],[ 1.])</td><td>(none)</td></tr><tr><td>adaptive_lengthscale_gp_multdim.V4</td><td>[[-0.30093654]</br> [-1.76772015]</br> [ 0.31062235]</br> [ 0.28930078]</br> [-0.72250372]</br> [-0.41670427]</br> [-0.32367693]</br> [-0.19413143]</br> [ 0.42549   ]</br> [-0.30023071]</br> [-0.56390981]</br> [ 1.08880606]</br> [ 0.9393986 ]</br> [ 0.3707648 ]</br> [-0.68234842]</br> [ 0.19129323]</br> [-0.3846574 ]</br> [-1.31181006]</br> [ 0.46552157]</br> [-0.26646597]]</td><td>N([ 0.],[ 1.])</td><td>(none)</td></tr><tr><td>adaptive_lengthscale_gp_multdim.kern_type.lengthscales</td><td>[ 0.9380313]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>adaptive_lengthscale_gp_multdim.kern_type.variance</td><td>[ 1.02740434]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>adaptive_lengthscale_gp_multdim.likelihood.variance</td><td>[  1.00000000e-06]</td><td>None</td><td>[FIXED]</td></tr><tr><td>adaptive_lengthscale_gp_multdim.mean_func.c</td><td>[ 3.]</td><td>None</td><td>[FIXED]</td></tr><tr><td>adaptive_lengthscale_gp_multdim.nonstat.signal_variance</td><td>[ 2.10523213]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr></table>

# %%
X_test = lhs(dim, n , criterion='center')
X_test_norm = (X_test - 0.5) /0.5
Y_test = np.array([objective(x) for x in X])[:, None]

# %%
samples.shape
# Out:
# (1000, 83)

# %%
plt.figure(figsize=(16, 4))
plt.plot(samples[:,10:80])
# Out:
# [<matplotlib.lines.Line2D at 0x1a247c9550>,
#  <matplotlib.lines.Line2D at 0x1a247c96d0>,
#  <matplotlib.lines.Line2D at 0x1a247c9790>,
#  <matplotlib.lines.Line2D at 0x1a247c9850>,
#  <matplotlib.lines.Line2D at 0x1a247c9910>,
#  <matplotlib.lines.Line2D at 0x1a247c99d0>,
#  <matplotlib.lines.Line2D at 0x1a247c9a90>,
#  <matplotlib.lines.Line2D at 0x1a247c9b50>,
#  <matplotlib.lines.Line2D at 0x1a247c9c10>,
#  <matplotlib.lines.Line2D at 0x1a247c9cd0>,
#  <matplotlib.lines.Line2D at 0x1a247c9d90>,
#  <matplotlib.lines.Line2D at 0x1a247c9e50>,
#  <matplotlib.lines.Line2D at 0x1a247c9f10>,
#  <matplotlib.lines.Line2D at 0x1a247c9fd0>,
#  <matplotlib.lines.Line2D at 0x1a247ec0d0>,
#  <matplotlib.lines.Line2D at 0x1a247ec190>,
#  <matplotlib.lines.Line2D at 0x1a247ec250>,
#  <matplotlib.lines.Line2D at 0x1a247ec310>,
#  <matplotlib.lines.Line2D at 0x1a247ec3d0>,
#  <matplotlib.lines.Line2D at 0x1a247ec490>,
#  <matplotlib.lines.Line2D at 0x1a2479e190>,
#  <matplotlib.lines.Line2D at 0x1a247ec610>,
#  <matplotlib.lines.Line2D at 0x1a247ec6d0>,
#  <matplotlib.lines.Line2D at 0x1a247ec790>,
#  <matplotlib.lines.Line2D at 0x1a247ec850>,
#  <matplotlib.lines.Line2D at 0x1a247ec910>,
#  <matplotlib.lines.Line2D at 0x1a247ec9d0>,
#  <matplotlib.lines.Line2D at 0x1a247eca90>,
#  <matplotlib.lines.Line2D at 0x1a247ecb50>,
#  <matplotlib.lines.Line2D at 0x1a247ecc10>,
#  <matplotlib.lines.Line2D at 0x1a247ec550>,
#  <matplotlib.lines.Line2D at 0x1a247ecd90>,
#  <matplotlib.lines.Line2D at 0x1a247ece50>,
#  <matplotlib.lines.Line2D at 0x1a247ecf10>,
#  <matplotlib.lines.Line2D at 0x1a247ecfd0>,
#  <matplotlib.lines.Line2D at 0x1a247f60d0>,
#  <matplotlib.lines.Line2D at 0x1a247f6190>,
#  <matplotlib.lines.Line2D at 0x1a247f6250>,
#  <matplotlib.lines.Line2D at 0x1a247f6310>,
#  <matplotlib.lines.Line2D at 0x1a247f63d0>,
#  <matplotlib.lines.Line2D at 0x1a247eccd0>,
#  <matplotlib.lines.Line2D at 0x1a247f6550>,
#  <matplotlib.lines.Line2D at 0x1a247f6610>,
#  <matplotlib.lines.Line2D at 0x1a247f66d0>,
#  <matplotlib.lines.Line2D at 0x1a247f6790>,
#  <matplotlib.lines.Line2D at 0x1a247f6850>,
#  <matplotlib.lines.Line2D at 0x1a247f6910>,
#  <matplotlib.lines.Line2D at 0x1a247f69d0>,
#  <matplotlib.lines.Line2D at 0x1a247f6a90>,
#  <matplotlib.lines.Line2D at 0x1a247f6b50>,
#  <matplotlib.lines.Line2D at 0x1a247f6490>,
#  <matplotlib.lines.Line2D at 0x1a247f6cd0>,
#  <matplotlib.lines.Line2D at 0x1a247f6d90>,
#  <matplotlib.lines.Line2D at 0x1a247f6e50>,
#  <matplotlib.lines.Line2D at 0x1a247f6f10>,
#  <matplotlib.lines.Line2D at 0x1a247f6fd0>,
#  <matplotlib.lines.Line2D at 0x1a248020d0>,
#  <matplotlib.lines.Line2D at 0x1a24802190>,
#  <matplotlib.lines.Line2D at 0x1a24802250>,
#  <matplotlib.lines.Line2D at 0x1a24802310>,
#  <matplotlib.lines.Line2D at 0x1a247f6c10>,
#  <matplotlib.lines.Line2D at 0x1a24802490>,
#  <matplotlib.lines.Line2D at 0x1a24802550>,
#  <matplotlib.lines.Line2D at 0x1a24802610>,
#  <matplotlib.lines.Line2D at 0x1a248026d0>,
#  <matplotlib.lines.Line2D at 0x1a24802790>,
#  <matplotlib.lines.Line2D at 0x1a24802850>,
#  <matplotlib.lines.Line2D at 0x1a24802910>,
#  <matplotlib.lines.Line2D at 0x1a248029d0>,
#  <matplotlib.lines.Line2D at 0x1a24802a90>]

# %%
X_test = lhs(dim, 100 , criterion='center')
X_test_norm = (X_test - 0.5) /0.5
Y_test = np.array([objective(x) for x in X_test])[:, None]

# %%
sample_df = m.get_samples_df(samples)
mean_f_mat = np.zeros(shape=(sample_df.shape[0], X_test_norm.shape[0]))
var_f_mat = np.zeros(shape=(sample_df.shape[0], X_test_norm.shape[0]))

# %%
for i, s in sample_df.iterrows():
    m.set_parameter_dict(s)
    mean_f, var_f = m.predict(X_test_norm)
    mean_f_mat[i, :] = mean_f[:,0]
    var_f_mat[i, :] = np.diag(var_f)

# %%
plt.figure(figsize=(12,8))
plt.scatter(mean_f_mat[5,:], Y_test)
